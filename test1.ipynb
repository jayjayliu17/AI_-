# %% [markdown]
# <a href="https://colab.research.google.com/github/jayjayliu17/AI_-/blob/main/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Jan  9 04:35:19 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P0    29W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
torch.__version__
# Out:
# '1.13.0+cu116'

# %%
import os
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/My Drive"

#os.chdir(path)
#os.listdir(path)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/
# Out:
# /content/drive

# %%
# %cd My\ Drive/人工智慧e
# Out:
# /content/drive/My Drive/人工智慧e

# %%
#!git clone https://github.com/ultralytics/yolov5.git #下載YOLOV5

# %%
# %ls
# Out:
#  benchmarks.py     DATA/        models/            segment/         utils/
#  best.pt          'DATA!!'/     __pycache__/       setup.cfg        valid/
#  CITATION.cff      detect.py    README.md          test/            val.py
#  classify/         export.py    README.zh-CN.md    train/
#  CONTRIBUTING.md   hubconf.py   requirements.txt   train.py
#  data/             LICENSE      runs/              tutorial.ipynb

# %%
# %cd yolov5/
# Out:
# /content/drive/MyDrive/人工智慧e/yolov5

# %%
# !python train.py --data ../GLASSES/data.yaml --cfg models/yolov5s.yaml --weights '' --batch-size 16 #放 16 筆資料進神經網路運算
# Out:
# requirements: YOLOv5 requirement "gitpython" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# requirements: 1 package updated per ['gitpython']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# train: weights=, cfg=models/yolov5s.yaml, data=../GLASSES/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch origin' timed out after 5 seconds
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --source DATA11
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=DATA11, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-33-g1752768 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5x summary: 322 layers, 86186872 parameters, 0 gradients
# image 1/5 /content/drive/MyDrive/人工智慧e/yolov5/DATA11/14364731361_9887739c1c_o.jpg: 320x640 8 with eyeglassess, 24 withouts, 58.4ms
# image 2/5 /content/drive/MyDrive/人工智慧e/yolov5/DATA11/14367699585_6223a94f66_o.jpg: 640x448 4 with eyeglassess, 13 withouts, 43.2ms
# ...
